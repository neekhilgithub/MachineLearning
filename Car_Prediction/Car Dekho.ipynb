# %% [markdown]
# ## Part 1: Data preprocessing

# %% [markdown]
# Dataset link: https://www.kaggle.com/datasets/nehalbirla/vehicle-dataset-from-cardekho

# %% [markdown]
# ### Importing the libraries and the dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("car_data.csv")
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %% [markdown]
# ### Data Explorartion

# %%
df.shape
# Out:
# (301, 9)

# %%
df.size
# Out:
# 2709

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
#CatogorialColumns
df.select_dtypes(include='object').columns
# Out:
# Index(['Car_Name', 'Fuel_Type', 'Seller_Type', 'Transmission'], dtype='object')

# %%
len(df.select_dtypes(include='object').columns)
# Out:
# 4

# %%
#NumericalColumns
df.select_dtypes(include=['int64', 'float64']).columns
# Out:
# Index(['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven', 'Owner'], dtype='object')

# %%
len(df.select_dtypes(include=['int64', 'float64']).columns)
# Out:
# 5

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %% [markdown]
# ### Dealing with missing values

# %%
df.isnull()
# Out:
#      Car_Name   Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0       False  False          False          False       False      False
# 1       False  False          False          False       False      False
# 2       False  False          False          False       False      False
# 3       False  False          False          False       False      False
# 4       False  False          False          False       False      False
# ..        ...    ...            ...            ...         ...        ...
# 296     False  False          False          False       False      False
# 297     False  False          False          False       False      False
# 298     False  False          False          False       False      False
# 299     False  False          False          False       False      False
# 300     False  False          False          False       False      False
#
#      Seller_Type  Transmission  Owner
# 0          False         False  False
# 1          False         False  False
# 2          False         False  False
# 3          False         False  False
# 4          False         False  False
# ..           ...           ...    ...
# 296        False         False  False
# 297        False         False  False
# 298        False         False  False
# 299        False         False  False
# 300        False         False  False
#
# [301 rows x 9 columns]

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isnull().values.sum()
# Out:
# 0

# %% [markdown]
# ### Modifify the dataset

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df = df.drop(columns='Car_Name')

# %%
df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
#add column
df['Current Year'] = 2020

# %%
df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current Year
# 0       Manual      0          2020
# 1       Manual      0          2020
# 2       Manual      0          2020
# 3       Manual      0          2020
# 4       Manual      0          2020

# %%
df['Year old'] = df['Current Year'] - df['Year']

# %%
df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current Year  Year old
# 0       Manual      0          2020         6
# 1       Manual      0          2020         7
# 2       Manual      0          2020         3
# 3       Manual      0          2020         9
# 4       Manual      0          2020         6

# %%
df = df.drop(columns=['Year', 'Current Year'])

# %%
df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Year old
# 0       Manual      0         6
# 1       Manual      0         7
# 2       Manual      0         3
# 3       Manual      0         9
# 4       Manual      0         6

# %% [markdown]
# ### Encoding the categorical data

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['Fuel_Type', 'Seller_Type', 'Transmission'], dtype='object')

# %%
len(df.select_dtypes(include='object').columns)
# Out:
# 3

# %%
df['Fuel_Type'].nunique()
# Out:
# 3

# %%
df['Fuel_Type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
df['Seller_Type'].nunique()
# Out:
# 2

# %%
df['Seller_Type'].unique()
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
df['Transmission'].nunique()
# Out:
# 2

# %%
df['Transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
df.shape
# Out:
# (301, 8)

# %%
# one hot encoding
df = pd.get_dummies(data=df, drop_first=True)

# %%
df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  Year old  \
# 0           3.35           5.59       27000      0         6
# 1           4.75           9.54       43000      0         7
# 2           7.25           9.85        6900      0         3
# 3           2.85           4.15        5200      0         9
# 4           4.60           6.87       42450      0         6
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0             False              True                   False
# 1              True             False                   False
# 2             False              True                   False
# 3             False              True                   False
# 4              True             False                   False
#
#    Transmission_Manual
# 0                 True
# 1                 True
# 2                 True
# 3                 True
# 4                 True

# %%
df.shape
# Out:
# (301, 9)

# %% [markdown]
# ### Correlation matrix

# %%
df_new = df.drop(columns='Selling_Price')

# %%
df_new.head()
# Out:
#    Present_Price  Kms_Driven  Owner  Year old  Fuel_Type_Diesel  \
# 0           5.59       27000      0         6             False
# 1           9.54       43000      0         7              True
# 2           9.85        6900      0         3             False
# 3           4.15        5200      0         9             False
# 4           6.87       42450      0         6              True
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0              True                   False                 True
# 1             False                   False                 True
# 2              True                   False                 True
# 3              True                   False                 True
# 4             False                   False                 True

# %%
df_new.corrwith(df['Selling_Price']).plot.bar(
    figsize=(16,9), title='Correlated with Selling Price', grid=True)
# Out:
# <Axes: title={'center': 'Correlated with Selling Price'}>

# %%
corr = df.corr()

# %%
#heat map
plt.figure(figsize=(16,9))
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Splitting the dataset

# %%
df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  Year old  \
# 0           3.35           5.59       27000      0         6
# 1           4.75           9.54       43000      0         7
# 2           7.25           9.85        6900      0         3
# 3           2.85           4.15        5200      0         9
# 4           4.60           6.87       42450      0         6
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0             False              True                   False
# 1              True             False                   False
# 2             False              True                   False
# 3             False              True                   False
# 4              True             False                   False
#
#    Transmission_Manual
# 0                 True
# 1                 True
# 2                 True
# 3                 True
# 4                 True

# %%
x = df.drop(columns='Selling_Price')

# %%
y= df['Selling_Price']

# %%
x.head()
# Out:
#    Present_Price  Kms_Driven  Owner  Year old  Fuel_Type_Diesel  \
# 0           5.59       27000      0         6             False
# 1           9.54       43000      0         7              True
# 2           9.85        6900      0         3             False
# 3           4.15        5200      0         9             False
# 4           6.87       42450      0         6              True
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0              True                   False                 True
# 1             False                   False                 True
# 2              True                   False                 True
# 3              True                   False                 True
# 4             False                   False                 True

# %%
y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
x_train.shape
# Out:
# (240, 8)

# %%
y_train.shape
# Out:
# (240,)

# %%
x_test.shape
# Out:
# (61, 8)

# %%
y_test.shape
# Out:
# (61,)

# %% [markdown]
# ## Part 2: Building the model

# %% [markdown]
# ### 1) Multiple linear regression

# %%
from sklearn.linear_model import LinearRegression
regression_lr = LinearRegression()
regression_lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regression_lr.predict(x_test)

# %%
y_pred
# Out:
# array([ 7.51749959, -0.38136   ,  4.2559471 ,  9.00719207, 14.4269339 ,
#         4.87144495,  3.50800415,  1.44729345,  5.3451756 ,  4.61435641,
#         2.26758534,  1.6209573 ,  5.0502457 ,  7.5592941 ,  8.60637169,
#        13.98391877,  7.32792948,  4.23074458, -0.43329109,  2.36959252,
#         4.98862734,  3.82566592,  6.43249291,  8.02059313, -1.89494718,
#         1.92952344, -0.82194725,  0.82000278,  0.0287008 ,  7.09763522,
#         3.56594643,  7.42982762,  0.72122573,  7.93570184,  3.51526022,
#         1.8051379 ,  5.54534144,  6.9878273 , -2.62961763,  9.08622868,
#         9.21468651, 20.02249841,  4.37997532,  3.85349481,  6.66353853,
#         9.8481939 ,  0.13251979,  1.68098927,  5.0992548 ,  7.35232556,
#         8.07177253,  4.17227139,  4.84915569, 20.36876087,  1.7479962 ,
#         1.30291959,  0.30682078,  1.98321103,  3.37503799,  0.87901548,
#         3.52730876])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9144342972228519

# %% [markdown]
# ### 2) Random forest regression

# %%
from sklearn.ensemble import RandomForestRegressor
regressor_rf = RandomForestRegressor()
regressor_rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = regressor_rf.predict(x_test)

# %%
y_pred
# Out:
# array([ 6.883 ,  0.4709,  4.5335,  8.976 , 15.4309,  5.298 ,  3.18  ,
#         0.4294,  3.9345,  4.699 ,  2.751 ,  0.7887,  4.8255,  7.1797,
#         7.7189, 15.2221,  6.5919,  3.994 ,  0.4561,  1.604 ,  3.15  ,
#         4.9975,  5.184 ,  9.6685,  0.2047,  0.7495,  0.2679,  0.7048,
#         0.4847,  4.3977,  2.5434,  5.963 ,  0.4883,  7.562 ,  3.4385,
#         1.1648,  5.7225,  5.3095,  0.2539,  8.1355,  7.9504, 23.2525,
#         4.8465,  4.431 ,  5.7785, 11.3492,  0.2357,  0.8241,  5.3365,
#         6.8305,  6.7926,  3.1015,  5.3635, 24.6425,  1.1787,  1.1404,
#         0.4612,  2.506 ,  3.612 ,  2.5546,  3.9612])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9603007706718821

# %% [markdown]
# ### 3) XG Boost Regressor

# %%
import xgboost as xgb

# %%
xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 10, alpha = 10, n_estimators = 10)

# %%
xg_reg.fit(x_train, y_train)
# Out:
# XGBRegressor(alpha=10, base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.3, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=10, n_jobs=None,
#              num_parallel_tree=None, ...)

# %%
y_pred = xg_reg.predict(x_test)

# %%
y_pred
# Out:
# array([ 6.474278 ,  2.674556 ,  4.5820565,  6.474278 ,  8.325615 ,
#         4.5820565,  4.2489247,  3.0076876,  4.6511807,  4.5203266,
#         3.9411252,  3.0076876,  4.5820565,  5.2557144,  6.474278 ,
#         5.037744 ,  5.2557144,  4.409718 ,  2.674556 ,  3.0076876,
#         4.6683307,  4.5820565,  4.9225826,  5.339364 ,  2.431879 ,
#         3.0076876,  2.674556 ,  2.8353493,  2.674556 ,  5.165811 ,
#         6.145407 ,  6.3019395,  2.8353493,  6.474278 ,  4.2776494,
#         3.0076876,  4.5992064,  6.3183265,  2.431879 ,  6.8861456,
#         6.474278 , 10.152652 ,  4.5820565,  4.5820565,  6.145988 ,
#         7.058484 ,  2.674556 ,  3.0076876,  4.5203266,  6.474278 ,
#         5.083376 ,  4.2742567,  4.5203266, 10.32499  ,  3.0076876,
#         3.0076876,  2.674556 ,  3.9411252,  4.2489247,  2.8353493,
#         4.763555 ], dtype=float32)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.47526866697369297

# %% [markdown]
# ### Part 4: Predicting a single observation

# %%
df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  Year old  \
# 0           3.35           5.59       27000      0         6
# 1           4.75           9.54       43000      0         7
# 2           7.25           9.85        6900      0         3
# 3           2.85           4.15        5200      0         9
# 4           4.60           6.87       42450      0         6
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0             False              True                   False
# 1              True             False                   False
# 2             False              True                   False
# 3             False              True                   False
# 4              True             False                   False
#
#    Transmission_Manual
# 0                 True
# 1                 True
# 2                 True
# 3                 True
# 4                 True

# %%
single_obs = [[8.50, 3500, 0, 5, 1, 0, 0, 1]]

# %%
regression_lr.predict(single_obs)
# Out:
# /Users/neekhilkumar/anaconda3/envs/geo/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([7.48930466])
# [CV] END criterion=mse, max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END criterion=mse, max_depth=40, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=auto, min_samples_leaf=10, min_samples_split=50, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=auto, min_samples_leaf=10, min_samples_split=50, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END criterion=mse, max_depth=40, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END criterion=mae, max_depth=40, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=mse, max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END criterion=mse, max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END criterion=mse, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=50, n_estimators=900; total time=   0.0s
# [CV] END criterion=mse, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=50, n_estimators=900; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END criterion=mse, max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END criterion=mse, max_depth=40, max_features=auto, min_samples_leaf=2, min_samples_split=50, n_estimators=900; total time=   0.0s
# [CV] END criterion=mse, max_depth=40, max_features=auto, min_samples_leaf=2, min_samples_split=50, n_estimators=900; total time=   0.0s
# [CV] END criterion=mse, max_depth=40, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END criterion=mae, max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=50, n_estimators=300; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=50, n_estimators=300; total time=   0.0s
# [CV] END criterion=mse, max_depth=30, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END criterion=mse, max_depth=30, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END criterion=mae, max_depth=30, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END criterion=mae, max_depth=40, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mae, max_depth=40, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=300; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=300; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=300; total time=   0.0s
# [CV] END criterion=mae, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END criterion=mae, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END criterion=mse, max_depth=40, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END criterion=mse, max_depth=40, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END criterion=mae, max_depth=40, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=mae, max_depth=40, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=mae, max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END criterion=mae, max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END criterion=mse, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END criterion=mse, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=700; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=700; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=700; total time=   0.0s
# [CV] END criterion=mse, max_depth=50, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END criterion=mse, max_depth=50, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END criterion=mse, max_depth=50, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END criterion=mse, max_depth=50, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END criterion=mse, max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   0.0s
# [CV] END criterion=mse, max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=800; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=800; total time=   0.0s

# %%
regressor_rf.predict(single_obs)
# Out:
# /Users/neekhilkumar/anaconda3/envs/geo/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([7.0225])

# %%
xg_reg.predict(single_obs)
# Out:
# array([6.474278], dtype=float32)
# [CV] END criterion=mse, max_depth=40, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=400; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END criterion=mae, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END criterion=mae, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END criterion=mae, max_depth=40, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=mae, max_depth=40, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=mse, max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END criterion=mse, max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END criterion=mae, max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END criterion=mae, max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END criterion=mse, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=50, n_estimators=900; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END criterion=mae, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END criterion=mae, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END criterion=mse, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END criterion=mse, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=700; total time=   0.0s
# [CV] END criterion=mse, max_depth=50, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END criterion=mse, max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=800; total time=   0.0s
# [CV] END criterion=mae, max_depth=40, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.0s
# [CV] END criterion=mae, max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=50, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mse, max_depth=40, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=400; total time=   0.0s
# [CV] END criterion=mae, max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END criterion=mae, max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END criterion=mae, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=auto, min_samples_leaf=10, min_samples_split=50, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=auto, min_samples_leaf=10, min_samples_split=50, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=auto, min_samples_leaf=10, min_samples_split=50, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END criterion=mae, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END criterion=mae, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END criterion=mae, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=700; total time=   0.0s
# [CV] END criterion=mse, max_depth=50, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END criterion=mse, max_depth=50, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END criterion=mse, max_depth=50, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END criterion=mse, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=mse, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=mse, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=800; total time=   0.0s
# [CV] END criterion=mae, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=50, n_estimators=400; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END criterion=mae, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=50, n_estimators=200; total time=   0.0s
# [CV] END criterion=mse, max_depth=40, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END criterion=mse, max_depth=50, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END criterion=mse, max_depth=50, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END criterion=mae, max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=50, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mse, max_depth=40, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=400; total time=   0.0s
# [CV] END criterion=mae, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END criterion=mae, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END criterion=mse, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END criterion=mse, max_depth=50, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END criterion=mse, max_depth=50, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END criterion=mse, max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   0.0s
# [CV] END criterion=mse, max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   0.0s
# [CV] END criterion=mse, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=mse, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=800; total time=   0.0s
# [CV] END criterion=mae, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END criterion=mae, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END criterion=mae, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=50, n_estimators=400; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END criterion=mae, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=50, n_estimators=200; total time=   0.0s
# [CV] END criterion=mae, max_depth=40, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.0s
# [CV] END criterion=mse, max_depth=40, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END criterion=mae, max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=50, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mse, max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END criterion=mae, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=50, n_estimators=300; total time=   0.0s
# [CV] END criterion=mse, max_depth=30, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END criterion=mse, max_depth=30, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END criterion=mae, max_depth=30, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=mae, max_depth=40, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mae, max_depth=40, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mae, max_depth=50, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END criterion=mae, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END criterion=mse, max_depth=40, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END criterion=mse, max_depth=40, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END criterion=mse, max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END criterion=mae, max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END criterion=mse, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=50, n_estimators=900; total time=   0.0s
# [CV] END criterion=mse, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=50, n_estimators=900; total time=   0.0s
# [CV] END criterion=mae, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END criterion=mae, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=50, n_estimators=400; total time=   0.0s
# [CV] END criterion=mae, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=50, n_estimators=200; total time=   0.0s
# [CV] END criterion=mae, max_depth=40, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.0s
# [CV] END criterion=mse, max_depth=40, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END criterion=mse, max_depth=50, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   0.0s

# %% [markdown]
# ## End of the Project
